# %%
import requests
import pandas as pd
import trove_key
import json

# %%
description = "BRUSTERS ICE CREAM BOW"
amount = 13.39
date = "2025-08-02"
user_id = "userid"
transaction_data = [description, amount, date, user_id]

transaction_data = {
    "description" : description,
    "amount" : amount,
    "date" : date,
    "user_id" : user_id
}

# %%
def get_merchant_info(transaction_data):
    url = "https://trove.headline.com/api/v1/transactions/enrich"
    headers = {
        'X-API-KEY': trove_key.TROVE_KEY,
        'content-type': 'application/json'
    }
    return requests.post(url, json=transaction_data, headers=headers)
merchant_intel = get_merchant_info(transaction_data).json()
for i in merchant_intel:
    print(f'{i}: {merchant_intel[i]}')
